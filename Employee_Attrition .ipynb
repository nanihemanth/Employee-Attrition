# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
import io
data = pd.read_csv("/content/attri.csv")

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 3099   50        No  Travel_Frequently        333  Research & Development
# 3100   34        No      Travel_Rarely       1440                   Sales
# 3101   42        No      Travel_Rarely       1210  Research & Development
# 3102   37        No      Travel_Rarely        674  Research & Development
# 3103   29        No      Travel_Rarely        441  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  3104.000000  3104.000000       3104.000000  3104.000000         3104.0
# mean     36.946198   809.490979          9.076353     2.896585            1.0
# std       9.264579   405.611066          8.086244     1.029661            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   469.750000          2.000000     2.000000            1.0
# 50%      36.000000   810.000000          7.000000     3.000000            1.0
# 75%      43.000000  1169.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     3104.000000              3104.000000  3104.000000     3104.000000
# mean       815.029961                 2.712307    65.701353        2.731959
# ...

# %% [markdown]
# # Dropping Unique Columns

# %%
l=[]
for i in data:
    l.append(data[i].unique())

for i in range(len(l)):
    if len(l[i])==1:
        print(i)
# Out:
# 8
# 21
# 26

# %%
##removing unique columns ==> EmployeeCount, Over18 and StandardHours
data=data.drop([data.columns[8],data.columns[21],data.columns[26]],axis=1)

# %% [markdown]
# # Removing Duplicates

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3099     True
# 3100     True
# 3101     True
# 3102     True
# 3103     True
# Length: 3104, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 1634

# %%
data.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %% [markdown]
# # Checking missing values

# %%
print(data.isnull().mean())
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# TrainingTimesLastYear       0.0
# WorkLifeBalance             0.0
# YearsAtCompany              0.0
# ...

# %% [markdown]
# # Checking Datatypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3104 entries, 0 to 3103
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3104 non-null   int64
#  1   Attrition                 3104 non-null   object
#  2   BusinessTravel            3104 non-null   object
#  3   DailyRate                 3104 non-null   int64
#  4   Department                3104 non-null   object
#  5   DistanceFromHome          3104 non-null   int64
#  6   Education                 3104 non-null   int64
#  7   EducationField            3104 non-null   object
#  8   EmployeeNumber            3104 non-null   int64
#  9   EnvironmentSatisfaction   3104 non-null   int64
#  10  Gender                    3104 non-null   object
#  11  HourlyRate                3104 non-null   int64
#  12  JobInvolvement            3104 non-null   int64
#  13  JobLevel                  3104 non-null   int64
# ...

# %% [markdown]
# # Renaming columns

# %%
data.rename(columns={'Education': 'LevelOfEducation'}, inplace=True)
data.rename(columns={'JobInvolvement': 'JobInvolvementRate'}, inplace=True)
data.rename(columns={'JobLevel': 'Designation'}, inplace=True)
data.rename(columns={'JobSatisfaction': 'JobSatisfactionLevel'}, inplace=True)
data.rename(columns={'YearsAtCompany': 'YearsInCurrentCompany'}, inplace=True)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  LevelOfEducation EducationField  EmployeeNumber  \
# 0                 1                 2  Life Sciences               1
# 1                 8                 1  Life Sciences               2
# 2                 2                 2          Other               4
# 3                 3                 4  Life Sciences               5
# 4                 2                 1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# ...

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
count=data['Attrition'].value_counts()
plt.pie(count,labels=count.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Percentage of Attrition')
plt.show()
##From the below pie chart we can see that the dataset is imbalanced.Not good for model creation.We need to balance the dataset.

# %%
sns.countplot(x="Gender",hue="Attrition",data=data)
##From the below countplot we can infer that Male employees left the company compared to female employees
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
x=data[data['Attrition']=='Yes']
count1=x['JobRole'].value_counts()
plt.pie(count1,labels=count1.index, autopct='%1.1f%%')
plt.axis('equal')
font_title = FontProperties(weight='bold', size=20)
plt.title('JobRole wise Attrition',fontproperties=font_title,color='red')
plt.show()
##From the below pie chart we can see that the attrition rate is high for Laboratoty Technicain job role followed by Sales Executive and Research Scientist.

# %%
sns.countplot(x="Department",hue="Attrition",data=data)
##Attrition is observed high in R and D Department followed by Sales Department.
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
age_bins = [18,33,45,60]  # Define the age bin boundaries
age_labels = ['18-33','34-45','46-60']  # Define the labels for each age group
data['AgeGroup'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels, right=False)
sns.set(style="whitegrid")
sns.countplot(data=data, x='AgeGroup', hue='Attrition')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Attrition by Age Group')
plt.show()
##From the graph it is clear that young people are shifting to other company

# %%
plt.figure(figsize=(9,7))
sns.boxplot(data=data, x='Department', y='MonthlyIncome')
plt.xlabel('Department')
plt.ylabel('MonthlyIncome')
plt.title('Salary by Department')
plt.show()
##We can see that average salary of Research and Development Department is low when compared with other two departments.So that is tha reason for the high employee attrition rate

# %%
prom_bins = [0,5,10,15]  # Define the age bin boundaries
prom_labels = ['0-5','6-10','11-15']  # Define the labels for each age group
data['PromGroup'] = pd.cut(data['YearsSinceLastPromotion'], bins=prom_bins, labels=prom_labels, right=False)
sns.set(style="whitegrid")
sns.countplot(data=data, x='PromGroup', hue='Attrition')
plt.xlabel('Promotion')
plt.ylabel('Count')
plt.title('Attrition by Years of Promotion')
plt.show()
##Attrition rate is high in the employees who has promoted between 0-5 years

# %%
mana_bins = [0,5,10,17]  # Define the age bin boundaries
mana_labels = ['0-5','6-10','11-17']  # Define the labels for each age group
data['manaGroup'] = pd.cut(data['YearsInCurrentRole'], bins=mana_bins, labels=mana_labels, right=False)
sns.set(style="whitegrid")
sns.countplot(data=data, x='manaGroup', hue='Attrition')
plt.xlabel('Years with same role')
plt.ylabel('Count')
plt.title('Years In Same Role')
plt.show()
##Attrition is not observed in the employees who are having strong bond with their current manager(from beginning)

# %%
plt.figure(figsize=(23,10))
sns.boxplot(data=data, x='JobRole', y='MonthlyIncome')
plt.xlabel('JobRole')
plt.ylabel('MonthlyIncome')
plt.title('Salary by JobRole')
plt.show()
##Average salary is high for Manager role followed by Research Director role so the attrition is less in those job roles.High Salary low attrition

# %%
by_g=data.groupby("YearsInCurrentCompany")['Attrition'].value_counts(normalize=False).unstack()
by_g.plot(kind='bar',stacked='False',figsize=(10,6))
plt.title('Years At Company of Employee')
plt.ylabel('no. of Employees')
plt.show()

# %% [markdown]
# EDA

# %%
level_of_education_mapping = {1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'}
performance_rating_mapping = {1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'}
work_life_balance_mapping = {1: 'Bad', 2: 'Good', 3: 'Better', 4: 'Best'}
col_mapping = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}

data['LevelOfEducation'].replace(level_of_education_mapping, inplace=True)
data['PerformanceRating'].replace(performance_rating_mapping, inplace=True)
data['WorkLifeBalance'].replace(work_life_balance_mapping, inplace=True)

for col_name in col:
    data[col_name].replace(col_mapping, inplace=True)

# %%
Attrition = data.query("Attrition == 'Yes'")
Attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 3073   24       Yes  Travel_Frequently        381  Research & Development
# 3081   28       Yes  Travel_Frequently        289  Research & Development
# 3090   29       Yes      Travel_Rarely        224  Research & Development
# 3096   40       Yes      Travel_Rarely        676  Research & Development
# 3098   31       Yes  Travel_Frequently        561  Research & Development
#
#       DistanceFromHome LevelOfEducation    EducationField  EmployeeNumber  \
# ...

# %%
def barplot(i):
    plt.figure(figsize=(8,4))
    plt.hist(Attrition[i], bins=10)
    plt.title(f'{i} x Attrition',fontsize=16, fontweight='bold')
    plt.xlabel(i,fontsize=12)
    plt.ylabel('Frequency',fontsize=12)
    plt.show()

# %%
barplot('BusinessTravel')
barplot('Department')
barplot('LevelOfEducation')
barplot('EnvironmentSatisfaction')
barplot('EducationField')
barplot('Gender')
barplot('JobInvolvementRate')
barplot('JobSatisfactionLevel')
barplot('WorkLifeBalance')
barplot('PerformanceRating')
barplot('JobRole')
barplot('MaritalStatus')
barplot('RelationshipSatisfaction')
barplot('OverTime')

# %%
def numeric_plot(i):
    plt.figure(figsize=(8,4))
    plt.hist(Attrition[i], bins=10)
    plt.title(f'{i} x Attrition',fontsize=16, fontweight='bold')
    plt.xlabel(i,fontsize=12)
    plt.ylabel('Frequency',fontsize=12)
    plt.show()

# %%
numeric_plot('Age')
numeric_plot('DailyRate')
numeric_plot('DistanceFromHome')
numeric_plot('HourlyRate')
numeric_plot('Designation')
numeric_plot('MonthlyIncome')
numeric_plot('MonthlyRate')
numeric_plot('NumCompaniesWorked')
numeric_plot('PercentSalaryHike')
numeric_plot('StockOptionLevel')
numeric_plot('TotalWorkingYears')
numeric_plot('TrainingTimesLastYear')
numeric_plot('YearsInCurrentCompany')
numeric_plot('YearsInCurrentRole')
numeric_plot('YearsSinceLastPromotion')
numeric_plot('YearsWithCurrManager')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = data

# Select the features (X) and target variable (y)
X = df[data.select_dtypes(include='number').columns.tolist()]
y = df['Attrition']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
y_test = lab.fit_transform(y_test)
y_train = lab.fit_transform(y_train)

# %%
from sklearn.linear_model import LogisticRegression
# Create a Logistic Regression Classifier
logistic_classifier = LogisticRegression(random_state=42)

# Fit the model to the training data
logistic_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = logistic_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy: 0.8534621578099839
# <Axes: >

# %%
from sklearn.metrics import classification_report
lr_report = classification_report(y_test, y_pred)
print("LR Classification Report:")
print(lr_report)
# Out:
# LR Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       522
#            1       0.62      0.21      0.32        99
#
#     accuracy                           0.85       621
#    macro avg       0.74      0.59      0.62       621
# weighted avg       0.83      0.85      0.82       621

# %%
from sklearn.neighbors import KNeighborsClassifier
# Create a K-Nearest Neighbors (KNN) Classifier
knn_classifier = KNeighborsClassifier()

# Fit the model to the training data
knn_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy: 0.8438003220611916
# <Axes: >

# %%
from sklearn.metrics import classification_report
knn_report = classification_report(y_test, y_pred)
print("KNN Classification Report:")
print(knn_report)
# Out:
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       522
#            1       0.52      0.33      0.40        99
#
#     accuracy                           0.84       621
#    macro avg       0.70      0.64      0.66       621
# weighted avg       0.82      0.84      0.83       621

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest (KNN) Classifier
rf_classifier = RandomForestClassifier()

# Fit the model to the training data
rf_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy: 0.9742351046698873
# <Axes: >

# %%
from sklearn.metrics import classification_report
rf_report = classification_report(y_test, y_pred)
print("RF Classification Report:")
print(rf_report)
# Out:
# RF Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       522
#            1       0.99      0.85      0.91        99
#
#     accuracy                           0.97       621
#    macro avg       0.98      0.92      0.95       621
# weighted avg       0.97      0.97      0.97       621

# %%
from sklearn.svm import SVC

# Create a SVM Classifier
svm_classifier = SVC()

# Fit the model to the training data
svm_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = svm_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy: 0.8776167471819646
# <Axes: >

# %%
from sklearn.metrics import classification_report
svm_report = classification_report(y_test, y_pred)
print("SVM Classification Report:")
print(svm_report)
# Out:
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       522
#            1       0.85      0.28      0.42        99
#
#     accuracy                           0.88       621
#    macro avg       0.86      0.64      0.68       621
# weighted avg       0.87      0.88      0.85       621

# %%
import xgboost as xgb
# Create an XGBoost classifier
xgb_classifier = xgb.XGBClassifier()

# Fit the model to the training data
xgb_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = xgb_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# Accuracy: 0.9790660225442834
# <Axes: >

# %%
from sklearn.metrics import classification_report
xg_report = classification_report(y_test, y_pred)
print("XG Classification Report:")
print(xg_report)
# Out:
# XG Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       522
#            1       0.96      0.91      0.93        99
#
#     accuracy                           0.98       621
#    macro avg       0.97      0.95      0.96       621
# weighted avg       0.98      0.98      0.98       621
